# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
#Your code here
import sqlite3 
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

import pandas as pd

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
c.execute("""select e.firstName, e.lastName, o.city, o.state 
             from employees e
             join offices o
             on e.officeCode = o.officeCode;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    firstName   lastName           city       state
# 0      Diane     Murphy  San Francisco          CA
# 1       Mary  Patterson  San Francisco          CA
# 2       Jeff   Firrelli  San Francisco          CA
# 3    William  Patterson         Sydney
# 4     Gerard     Bondur          Paris
# 5    Anthony        Bow  San Francisco          CA
# 6     Leslie   Jennings  San Francisco          CA
# 7     Leslie   Thompson  San Francisco          CA
# 8      Julie   Firrelli         Boston          MA
# 9      Steve  Patterson         Boston          MA
# 10  Foon Yue      Tseng            NYC          NY
# 11    George     Vanauf            NYC          NY
# 12      Loui     Bondur          Paris
# 13    Gerard  Hernandez          Paris
# 14    Pamela   Castillo          Paris
# 15     Larry       Bott         London
# 16     Barry      Jones         London
# 17      Andy     Fixter         Sydney
# 18     Peter      Marsh         Sydney
# 19       Tom       King         Sydney
# 20      Mami      Nishi          Tokyo  Chiyoda-Ku
# 21   Yoshimi       Kato          Tokyo  Chiyoda-Ku
# 22    Martin     Gerard          Paris

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
c.execute("""select c.contactFirstName, c.contactLastName, o.orderNumber, o.orderDate, o.status 
             from customers c
             join orders o
             on c.customerNumber = o.customerNumber;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     contactFirstName contactLastName orderNumber   orderDate      status
# 0            Carine          Schmitt       10123  2003-05-20     Shipped
# 1            Carine          Schmitt       10298  2004-09-27     Shipped
# 2            Carine          Schmitt       10345  2004-11-25     Shipped
# 3               Jean            King       10124  2003-05-21     Shipped
# 4               Jean            King       10278  2004-08-06     Shipped
# 5               Jean            King       10346  2004-11-29     Shipped
# 6              Peter        Ferguson       10120  2003-04-29     Shipped
# 7              Peter        Ferguson       10125  2003-05-21     Shipped
# 8              Peter        Ferguson       10223  2004-02-20     Shipped
# 9              Peter        Ferguson       10342  2004-11-24     Shipped
# 10             Peter        Ferguson       10347  2004-11-29     Shipped
# 11           Janine          Labrune       10275  2004-07-23     Shipped
# 12           Janine          Labrune       10315  2004-10-29     Shipped
# 13           Janine          Labrune       10375  2005-02-03     Shipped
# 14           Janine          Labrune       10425  2005-05-31  In Process
# 15            Jonas       Bergulfsen       10103  2003-01-29     Shipped
# 16            Jonas       Bergulfsen       10158  2003-10-10     Shipped
# 17            Jonas       Bergulfsen       10309  2004-10-15     Shipped
# 18            Jonas       Bergulfsen       10325  2004-11-05     Shipped
# 19             Susan          Nelson       10113  2003-03-26     Shipped
# 20             Susan          Nelson       10135  2003-07-02     Shipped
# 21             Susan          Nelson       10142  2003-08-08     Shipped
# 22             Susan          Nelson       10182  2003-11-12     Shipped
# 23             Susan          Nelson       10229  2004-03-11     Shipped
# 24             Susan          Nelson       10271  2004-07-20     Shipped
# 25             Susan          Nelson       10282  2004-08-20     Shipped
# 26             Susan          Nelson       10312  2004-10-21     Shipped
# 27             Susan          Nelson       10335  2004-11-19     Shipped
# 28             Susan          Nelson       10357  2004-12-10     Shipped
# 29             Susan          Nelson       10368  2005-01-19     Shipped
# ..               ...             ...         ...         ...         ...
# 296               Yu            Choi       10242  2004-04-20     Shipped
# 297               Yu            Choi       10319  2004-11-03     Shipped
# 298          Martín           Sommer       10126  2003-05-28     Shipped
# 299          Martín           Sommer       10214  2004-01-26     Shipped
# 300          Martín           Sommer       10348  2004-11-01     Shipped
# 301          Violeta         Benitez       10166  2003-10-21     Shipped
# 302          Violeta         Benitez       10321  2004-11-04     Shipped
# 303          Violeta         Benitez       10388  2005-03-03     Shipped
# 304             Sean        Clenahan       10193  2003-11-21     Shipped
# 305             Sean        Clenahan       10265  2004-07-02     Shipped
# 306             Sean        Clenahan       10415  2005-05-09    Disputed
# 307           Franco         Ricotti       10157  2003-10-09     Shipped
# 308           Franco         Ricotti       10218  2004-02-09     Shipped
# 309            Steve        Thompson       10199  2003-12-01     Shipped
# 310            Steve        Thompson       10215  2004-01-29     Shipped
# 311      José Pedro             Roel       10184  2003-11-14     Shipped
# 312      José Pedro             Roel       10303  2004-10-06     Shipped
# 313             Rosa         Salazar       10109  2003-03-10     Shipped
# 314             Rosa         Salazar       10236  2004-04-03     Shipped
# 315             Rosa         Salazar       10331  2004-11-17     Shipped
# 316              Sue          Taylor       10149  2003-09-12     Shipped
# 317              Sue          Taylor       10219  2004-02-10     Shipped
# 318          Thomas            Smith       10186  2003-11-14     Shipped
# 319          Thomas            Smith       10213  2004-01-22     Shipped
# 320          Valarie          Franco       10207  2003-12-09     Shipped
# 321          Valarie          Franco       10243  2004-04-26     Shipped
# 322             Tony         Snowden       10138  2003-07-07     Shipped
# 323             Tony         Snowden       10179  2003-11-11   Cancelled
# 324             Tony         Snowden       10360  2004-12-16     Shipped
# 325             Tony         Snowden       10399  2005-04-01     Shipped
#
# [326 rows x 5 columns]

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here
c.execute("""select c.contactFirstName, c.contactLastName, p.amount, p.paymentDate
             from customers c
             join payments p
             on c.customerNumber = p.customerNumber;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here
c.execute("""SELECT cu.contactFirstName, cu.contactLastName, o.orderDate, od.quantityOrdered, p.productName
             FROM customers cu
             LEFT JOIN orders o
             ON cu.customerNumber = o.customerNumber
             LEFT JOIN orderdetails od
             ON o.orderNumber = od.orderNumber
             LEFT JOIN products p
             ON p.productCode = od.productCode;""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#      contactFirstName contactLastName   orderDate quantityOrdered  \
# 0             Carine          Schmitt  2003-05-20              26
# 1             Carine          Schmitt  2003-05-20              46
# 2             Carine          Schmitt  2003-05-20              34
# 3             Carine          Schmitt  2003-05-20              50
# 4             Carine          Schmitt  2004-09-27              39
# 5             Carine          Schmitt  2004-09-27              32
# 6             Carine          Schmitt  2004-11-25              43
# 7                Jean            King  2003-05-21              21
# 8                Jean            King  2003-05-21              42
# 9                Jean            King  2003-05-21              42
# 10               Jean            King  2003-05-21              36
# 11               Jean            King  2003-05-21              23
# 12               Jean            King  2003-05-21              22
# 13               Jean            King  2003-05-21              45
# 14               Jean            King  2003-05-21              22
# 15               Jean            King  2003-05-21              32
# 16               Jean            King  2003-05-21              25
# 17               Jean            King  2003-05-21              49
# 18               Jean            King  2003-05-21              43
# 19               Jean            King  2003-05-21              46
# 20               Jean            King  2004-08-06              34
# 21               Jean            King  2004-08-06              23
# 22               Jean            King  2004-08-06              29
# 23               Jean            King  2004-08-06              29
# 24               Jean            King  2004-08-06              39
# 25               Jean            King  2004-08-06              42
# 26               Jean            King  2004-08-06              31
# 27               Jean            King  2004-08-06              35
# 28               Jean            King  2004-08-06              31
# 29               Jean            King  2004-08-06              25
# ...               ...             ...         ...             ...
# 2990             Tony         Snowden  2003-11-11              34
# 2991             Tony         Snowden  2003-11-11              23
# 2992             Tony         Snowden  2003-11-11              25
# 2993             Tony         Snowden  2003-11-11              39
# 2994             Tony         Snowden  2004-12-16              50
# 2995             Tony         Snowden  2004-12-16              41
# 2996             Tony         Snowden  2004-12-16              46
# 2997             Tony         Snowden  2004-12-16              29
# 2998             Tony         Snowden  2004-12-16              29
# 2999             Tony         Snowden  2004-12-16              40
# 3000             Tony         Snowden  2004-12-16              40
# 3001             Tony         Snowden  2004-12-16              22
# 3002             Tony         Snowden  2004-12-16              31
# 3003             Tony         Snowden  2004-12-16              49
# 3004             Tony         Snowden  2004-12-16              36
# 3005             Tony         Snowden  2004-12-16              22
# 3006             Tony         Snowden  2004-12-16              32
# 3007             Tony         Snowden  2004-12-16              26
# 3008             Tony         Snowden  2004-12-16              30
# 3009             Tony         Snowden  2004-12-16              35
# 3010             Tony         Snowden  2004-12-16              31
